# %% [markdown]
# # Final Project - Word **Cloud**

# %%
import pandas as pd 
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS

#mpl.rcParams['figure.figsize']=(8.0,6.0)    #(6.0,4.0)
mpl.rcParams['font.size']=22                #10 
mpl.rcParams['savefig.dpi']=100             #72 
mpl.rcParams['figure.subplot.bottom']=.1

# %%
stopwords = set(STOPWORDS)
from google.colab import files
file_contents = files.upload()
# Out:
#      <input type="file" id="files-7aeb1fe5-5b81-42bc-ad5c-69af0cc2b87c" name="files[]" multiple disabled />
#      <output id="result-7aeb1fe5-5b81-42bc-ad5c-69af0cc2b87c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving luke.txt to luke (1).txt

# %%
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=290,
                          max_font_size=44, 
                          random_state=42
                         ).generate(str(file_contents))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
#plt.figure(figsize=(20,10))
plt.axis('off')
plt.figure( figsize=(100,5) )
plt.show()
fig.savefig("word1.png", dpi=9000)
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7fde79aa7e48>
